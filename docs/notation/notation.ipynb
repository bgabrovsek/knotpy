# %%
import knotpy as kp
k = kp.knot("6_2")
list(k.nodes)
list(k.endpoints)
# Out:
# [b3,
#  c0,
#  c3,
#  b0,
#  a3,
#  d0,
#  e3,
#  a0,
#  a1,
#  e2,
#  f3,
#  a2,
#  b1,
#  f2,
#  f1,
#  e0,
#  d3,
#  f0,
#  c1,
#  b2,
#  e1,
#  d2,
#  d1,
#  c2]

# %%
k.endpoints
# Out:
# a → (None None None None), b → (None None None None), c → (None None None None), d → (None None None None), e → (None None None None), f → (None None None None)

# %%
k
# Out:
# Diagram named 6_2 a → X(b3 c0 c3 b0), b → X(a3 d0 e3 a0), c → X(a1 e2 f3 a2), d → X(b1 f2 f1 e0), e → X(d3 f0 c1 b2), f → X(e1 d2 d1 c2)
